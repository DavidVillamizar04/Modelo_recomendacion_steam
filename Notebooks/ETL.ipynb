# %%
# Se importan las librerias necesarias
import pandas as pd
import gzip as gz
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# # ETL GAMES

# %%
# Usando la libreria gzip descomprimimos el archivo steam_games para poder leerlos con pandas
with gz.open('../Datasets/JSON/steam_games.json.gz') as desc:
    contenido1 = desc.read()

# Leemos el archivo ya descompreso usando pandas para combertirlo en un dataframe
games = pd.read_json(contenido1.decode('utf-8'), lines=True)
games.info()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7172\1610197785.py:6: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   games = pd.read_json(contenido1.decode('utf-8'), lines=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
# ...

# %%
# Eliminaremos los valores nulos para tener un dataframe mas pequeño y mas concreto
# Quedaran las filas que tengan por lo menos la mitad de datos completos

games = games.dropna(thresh=6)
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32134 entries, 88310 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32134 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30757 non-null  object
#  10  early_access  32134 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 3.4+ MB

# %%
# Extraemos el año de la columna release
games['release_year'] = games['release_date'].str.extract(r"(\d{4})")
games.head()
# Out:
#               publisher                                             genres  \
# 88310         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313              彼岸领域                        [Action, Adventure, Casual]
# 88314              None                                               None
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88314            Log Challenge                     None
#
#                                                      url release_date  \
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# ...

# %%
df_games = games[["genres", "release_year", "id", "app_name", "title", "tags", "developer","price"]]
df_games.head()
# Out:
#                                                   genres release_year  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]         2018
# 88311               [Free to Play, Indie, RPG, Strategy]         2018
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]         2017
# 88313                        [Action, Adventure, Casual]         2017
# 88314                                               None          NaN
#
#              id                 app_name                    title  \
# 88310  761140.0      Lost Summoner Kitty      Lost Summoner Kitty
# 88311  643980.0                Ironbound                Ironbound
# 88312  670290.0  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313  767400.0                  弹炸人2222                  弹炸人2222
# 88314  773570.0            Log Challenge                     None
#
#                                                     tags         developer  \
# ...

# %%
df_games['price'] = df_games['price'].fillna(0)
df_games['price'].isna().sum()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7172\60180453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_games['price'] = df_games['price'].fillna(0)
# 0

# %%
df_games["price"] = df_games["price"].apply(lambda fila : 0.0 if type(fila)==str else float(fila))
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32134 entries, 88310 to 120444
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        28852 non-null  object
#  1   release_year  29967 non-null  object
#  2   id            32133 non-null  float64
#  3   app_name      32133 non-null  object
#  4   title         30085 non-null  object
#  5   tags          31972 non-null  object
#  6   developer     28836 non-null  object
#  7   price         32134 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 2.2+ MB
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7172\552633397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_games = df_games.explode('genres').reset_index(drop=True)
df_games
# Out:
#            genres release_year        id             app_name  \
# 0          Action         2018  761140.0  Lost Summoner Kitty
# 1          Casual         2018  761140.0  Lost Summoner Kitty
# 2           Indie         2018  761140.0  Lost Summoner Kitty
# 3      Simulation         2018  761140.0  Lost Summoner Kitty
# 4        Strategy         2018  761140.0  Lost Summoner Kitty
# ...           ...          ...       ...                  ...
# 74831      Racing         2018  610660.0        Russian Roads
# 74832  Simulation         2018  610660.0        Russian Roads
# 74833      Casual         2017  658870.0  EXIT 2 - Directions
# 74834       Indie         2017  658870.0  EXIT 2 - Directions
# 74835        None          NaN  681550.0          Maze Run VR
#
#                      title                                               tags  \
# 0      Lost Summoner Kitty      [Strategy, Action, Indie, Casual, Simulation]
# ...

# %%
games = df_games[['genres','developer', 'release_year','app_name','id','price']]

# %%
games.to_parquet('../Datasets/games.parquet',compression='snappy', index=False)

# %% [markdown]
# # ETL Reviews

# %%
# Usando la libreria gzip descomprimimos el archivo user_reviews para poder leerlos con pandas
with gz.open('../Datasets/JSON/user_reviews.json.gz') as desc:
    contenido2 = desc.readlines()

#Transformamos las lineas a registros json
reviews = [eval(line.strip()) for line in contenido2]

# Leemos el archivo ya descompreso usando pandas
reviews = pd.DataFrame(reviews)
print(reviews.info())
reviews.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25799 entries, 0 to 25798
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25799 non-null  object
#  1   user_url  25799 non-null  object
#  2   reviews   25799 non-null  object
# dtypes: object(3)
# memory usage: 604.8+ KB
# None
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# ...

# %%
# Eliminamos la columna 'user_url' la cual no usaremos
reviews = reviews.drop(columns=['user_url'],axis=1)
reviews2 = reviews

# %%
#Desanidamos los datos de la columna Reviews
review_desanidada = []

for index, row in reviews.iterrows():
    user_id = row['user_id']
    reviews = row['reviews']
    
    for i in reviews:   
        new_row = {
        'funny': i.get('funny', ''),
        'posted': i.get('posted', ''),
        'last_edited': i.get('last_edited', ''),
        'item_id': i.get('item_id', ''),
        'helpful': i.get('helpful', ''),
        'recommend': i.get('recommend', bool),
        'review': i.get('review', '')
        }
        
        review_desanidada.append(new_row)

# %%
# Convertimos en dataframe los datos desanidados anteriormente
review_desanidada = pd.DataFrame(review_desanidada)
review_desanidada.head(5)
# Out:
#   funny                     posted last_edited item_id  \
# 0         Posted November 5, 2011.                1250
# 1            Posted July 15, 2011.               22200
# 2           Posted April 21, 2011.               43110
# 3            Posted June 24, 2014.              251610
# 4        Posted September 8, 2013.              227300
#
#                                            helpful  recommend  \
# 0                                   No ratings yet       True
# 1                                   No ratings yet       True
# 2                                   No ratings yet       True
# 3  15 of 20 people (75%) found this review helpful       True
# 4     0 of 1 people (0%) found this review helpful       True
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1               It's unique and worth a playthrough.
# 2  Great atmosphere. The gunplay can be a bit chu...
# ...

# %%
#Creamos la funcion para el analizador de sentimientos
analizador = SentimentIntensityAnalyzer()

def analizador_de_sentimientos (review):
    # Se obtiene el puntaje de polaridad del sentimiento
    compound_score = analizador.polarity_scores(str(review))["compound"]

    # Clasificamos la polaridad segun lo requerido teniendo en cuenta que 0 es negativo, 1 es neutral y 2 es positivo
    if compound_score < 0:
        return 0  
    elif compound_score == 0:
        return 1  
    else:
        return 2

# %%
# Agregamos la columna de analisis de sentimiento a la fila de review
review_desanidada['Sentiment_analysis'] = review_desanidada['review'].apply(analizador_de_sentimientos)
review_desanidada
# Out:
#                                   funny                     posted  \
# 0                                         Posted November 5, 2011.
# 1                                            Posted July 15, 2011.
# 2                                           Posted April 21, 2011.
# 3                                            Posted June 24, 2014.
# 4                                        Posted September 8, 2013.
# ...                                 ...                        ...
# 59300                                              Posted July 10.
# 59301                                               Posted July 8.
# 59302  1 person found this review funny             Posted July 3.
# 59303                                              Posted July 20.
# 59304                                               Posted July 2.
#
#       last_edited item_id                                          helpful  \
# 0                    1250                                   No ratings yet
# ...

# %%
review_desanidada = review_desanidada.drop(['funny','helpful','review'], axis=1)
review_desanidada.head()
# Out:
#                       posted last_edited item_id  recommend  \
# 0   Posted November 5, 2011.                1250       True
# 1      Posted July 15, 2011.               22200       True
# 2     Posted April 21, 2011.               43110       True
# 3      Posted June 24, 2014.              251610       True
# 4  Posted September 8, 2013.              227300       True
#
#    Sentiment_analysis
# 0                   2
# 1                   2
# 2                   2
# 3                   2
# 4                   2

# %%
#Fecha de last_edited
review_desanidada["Year"] = review_desanidada["last_edited"].str.extract(r"(\d{4})") #year con last_edited
review_desanidada["Year 2"] = review_desanidada["posted"].str.extract(r"(\d{4})").fillna(0)
review_desanidada["Year"].fillna(review_desanidada["Year 2"], inplace=True)
review_desanidada.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28468\295171563.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   review_desanidada["Year"].fillna(review_desanidada["Year 2"], inplace=True)
#                       posted last_edited item_id  recommend  \
# 0   Posted November 5, 2011.                1250       True
# 1      Posted July 15, 2011.               22200       True
# 2     Posted April 21, 2011.               43110       True
# 3      Posted June 24, 2014.              251610       True
# ...

# %%
nan_sum = review_desanidada["Year 2"].isnull().sum()
nan_sum
# Out:
# 0

# %%
df_Score = review_desanidada[["item_id", "recommend", "Sentiment_analysis", "Year"]].drop_duplicates()
df_Score
# Out:
#       item_id  recommend  Sentiment_analysis  Year
# 0        1250       True                   2  2011
# 1       22200       True                   2  2011
# 2       43110       True                   2  2011
# 3      251610       True                   2  2014
# 4      227300       True                   2  2013
# ...       ...        ...                 ...   ...
# 59281  220090       True                   1     0
# 59282  262850       True                   1     0
# 59285  298110      False                   1     0
# 59286  431510       True                   2     0
# 59299     130       True                   2     0
#
# [12652 rows x 4 columns]

# %%
review_final = pd.concat([reviews2['user_id'], df_Score], axis=1)
review_final = review_final.dropna()
review_final
# Out:
#                  user_id item_id recommend  Sentiment_analysis  Year
# 0      76561197970982479    1250      True                 2.0  2011
# 1                js41637   22200      True                 2.0  2011
# 2              evcentric   43110      True                 2.0  2011
# 3                  doctr  251610      True                 2.0  2014
# 4              maplemage  227300      True                 2.0  2013
# ...                  ...     ...       ...                 ...   ...
# 25778       ChrisCoroner  268870      True                 2.0     0
# 25781        KinkyyyCSGO  242050      True                 2.0  2015
# 25784  76561198272389051  215280      True                 2.0  2013
# 25792  76561198296402247   91700      True                 1.0  2013
# 25796  76561198310819422  208730     False                 1.0  2014
#
# [7973 rows x 5 columns]

# %%
review_final['Year'] = review_final['Year'].astype(str).astype(int)
review_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7973 entries, 0 to 25796
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             7973 non-null   object
#  1   item_id             7973 non-null   object
#  2   recommend           7973 non-null   object
#  3   Sentiment_analysis  7973 non-null   float64
#  4   Year                7973 non-null   int32
# dtypes: float64(1), int32(1), object(3)
# memory usage: 342.6+ KB

# %%
review_final.to_parquet('../Datasets/reviews.parquet',compression='snappy', index=False)

# %% [markdown]
# # ETL items

# %%
with gz.open('../Datasets/JSON/users_items.json.gz') as desc:
    contenido3 = desc.readlines()

#Transformamos las lineas a registros json
items = [eval(line.strip()) for line in contenido3]

# Leemos el archivo ya descompreso usando pandas
items = pd.DataFrame(items)
print(items.info())
items.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB
# None
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# ...

# %%
items_desanidado = []

for index, row in items.iterrows():
    user_id = row['user_id']
    items_count = row['items_count']
    steam_id = row['steam_id']
    user_url = row['user_url']
    items = row['items']
    
    for i in items:   
        new_row = {
        'user_id': user_id,
        'items_count': items_count,
        'steam_id' : steam_id,
        'user_url' : user_url,
        'item_id': i.get('item_id', ''),
        'item_name': i.get('item_name', ''),
        'playtime_forever': i.get('playtime_forever', ''),
        'playtime_2weeks': i.get('playtime_2weeks', '')
        }
        
        items_desanidado.append(new_row)

desanidado = pd.DataFrame(items_desanidado)
desanidado
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5153204  76561198329548331            7  76561198329548331
# 5153205  76561198329548331            7  76561198329548331
# 5153206  76561198329548331            7  76561198329548331
# 5153207  76561198329548331            7  76561198329548331
# 5153208  76561198329548331            7  76561198329548331
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1        http://steamcommunity.com/profiles/76561197970...      20
# ...

# %%
user_items = desanidado[['user_id','steam_id','item_id','item_name','playtime_forever']]
user_items.head(5)
# Out:
#              user_id           steam_id item_id                  item_name  \
# 0  76561197970982479  76561197970982479      10             Counter-Strike
# 1  76561197970982479  76561197970982479      20      Team Fortress Classic
# 2  76561197970982479  76561197970982479      30              Day of Defeat
# 3  76561197970982479  76561197970982479      40         Deathmatch Classic
# 4  76561197970982479  76561197970982479      50  Half-Life: Opposing Force
#
#    playtime_forever
# 0                 6
# 1                 0
# 2                 7
# 3                 0
# 4                 0

# %%
user_items.to_parquet('../Datasets/user_items.parquet',compression='snappy',index=False)
